# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-07-07*

# %%
import sys
sys.path.append('../../src/')
from namelist import *
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'PRES'
varch = '气压'

title = 'Pressure'
units = 'hPa'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(mcipfile,var,shpall,obsall,varch)
# Out:
# Get the PRES in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param       value
# 0  obs mean  997.224900
# 1  sim mean  980.567200
# 2         R    0.967564
# 3        MB  -16.657700
# 4      RMSE   16.671219
# 5       IOA    0.235237

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(mcipfile,var,shpurban,obsurban,varch)
# Out:
# Get the PRES in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1001.427644
# 1  sim mean  1000.882141
# 2         R     0.959926
# 3        MB    -0.545502
# 4      RMSE     0.926809
# 5       IOA     0.969133

# %% [markdown]
# 郊区或通道区的范围不好处理，因此以下暂不考虑
# ## 安庆市通道区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/channel.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PRES in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1013.459048
# 1  sim mean   996.526123
# 2         R     0.992212
# 3        MB   -16.932925
# 4      RMSE    16.952261
# 5       IOA     0.428745
