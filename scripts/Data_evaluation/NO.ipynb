# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-07-07*

# %%
import sys
sys.path.append('../../src/')
import ModelEvaLib as me
from namelist import *

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'NO'
varch = 'NO'

title = '$NO$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpall,obsall,varch)
# Out:
# Get the NO in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the NO in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  2.086863
# 1  sim mean  0.585510
# 2         R  0.370071
# 3        MB -1.501352
# 4      RMSE  1.754496
# 5       IOA  0.410906

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpurban,obsurban,varch)
# Out:
# Get the NO in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the NO in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  2.046134
# 1  sim mean  1.714193
# 2         R  0.208799
# 3        MB -0.331941
# 4      RMSE  2.713346
# 5       IOA  0.420519
