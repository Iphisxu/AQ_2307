# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-07-07*

# %%
import sys
sys.path.append('../../src/')
from namelist import *
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'SFC_TMP'
varch = '气温'

title = 'T2'
units = '℃'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(mcipfile,var,shpall,obsall,varch)
# Out:
# Get the SFC_TMP in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气温 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  26.804490
# 1  sim mean  25.909000
# 2         R   0.885376
# 3        MB  -0.895490
# 4      RMSE   1.857933
# 5       IOA   0.922861

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(mcipfile,var,shpurban,obsurban,varch)
# Out:
# Get the SFC_TMP in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气温 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  26.791734
# 1  sim mean  27.050112
# 2         R   0.813836
# 3        MB   0.258377
# 4      RMSE   2.103076
# 5       IOA   0.896367
