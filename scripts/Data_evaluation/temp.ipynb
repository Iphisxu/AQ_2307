# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-08-09*

# %%
import sys
sys.path.append('../../src/')
from namelist import *
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'SFC_TMP'
varch = '气温'

title = 'T2'
units = '℃'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(mcipfile,var,shpall,obsall,varch)
# Out:
# Get the SFC_TMP in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气温 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  29.120117
# 1  sim mean  28.395439
# 2         R   0.749585
# 3        MB  -0.724678
# 4      RMSE   2.135490
# 5       IOA   0.850269

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(mcipfile,var,shpurban,obsurban,varch)
# Out:
# Get the SFC_TMP in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气温 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  29.116371
# 1  sim mean  29.653904
# 2         R   0.652642
# 3        MB   0.537533
# 4      RMSE   2.492661
# 5       IOA   0.801998
