# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-07-07*

# %%
import sys
sys.path.append('../../src/')
from namelist import *
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'RH'
varch = '湿度'

title = 'RH'
units = '%'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(mcipfile,var,shpall,obsall,varch)
# Out:
# Get the RH in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 湿度 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  76.564672
# 1  sim mean  67.644562
# 2         R   0.867663
# 3        MB  -8.920110
# 4      RMSE  12.715066
# 5       IOA   0.854979

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(mcipfile,var,shpurban,obsurban,varch)
# Out:
# Get the RH in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 湿度 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  78.731944
# 1  sim mean  66.732292
# 2         R   0.821874
# 3        MB -11.999652
# 4      RMSE  16.024660
# 5       IOA   0.794447
