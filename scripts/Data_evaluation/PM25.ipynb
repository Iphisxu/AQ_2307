# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-07-07*

# %%
import sys
sys.path.append('../../src/')
import ModelEvaLib as me
from namelist import *

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'PM25'
varch = 'PM2.5'

title = '$PM_{2.5}$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpall,obsall,varch)
# Out:
# Get the PM25 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the PM2.5 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  19.747839
# 1  sim mean  29.314312
# 2         R   0.472006
# 3        MB   9.566472
# 4      RMSE  19.051735
# 5       IOA   0.535103

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpurban,obsurban,varch)
# Out:
# Get the PM25 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the PM2.5 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  21.787847
# 1  sim mean  31.393021
# 2         R   0.435728
# 3        MB   9.605173
# 4      RMSE  21.606241
# 5       IOA   0.550455
