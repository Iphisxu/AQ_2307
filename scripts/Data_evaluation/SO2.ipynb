# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-07-07*

# %%
import sys
sys.path.append('../../src/')
import ModelEvaLib as me
from namelist import *

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'SO2'
varch = 'SO2'

title = '$SO_2$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpall,obsall,varch)
# Out:
# Get the SO2 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the SO2 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  7.264299
# 1  sim mean  7.121906
# 2         R  0.143758
# 3        MB -0.142392
# 4      RMSE  4.301018
# 5       IOA  0.342490

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpurban,obsurban,varch)
# Out:
# Get the SO2 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the SO2 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  9.151019
# 1  sim mean  9.910460
# 2         R  0.008839
# 3        MB  0.759441
# 4      RMSE  7.640120
# 5       IOA  0.310223
