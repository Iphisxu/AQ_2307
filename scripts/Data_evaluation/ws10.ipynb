# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-08-09*

# %%
import sys
sys.path.append('../../src/')
from namelist import *
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'WSPD10'
varch = '风速'

title = 'WS10'
units = 'm/s'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(mcipfile,var,shpall,obsall,varch)
# Out:
# Get the WSPD10 in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 风速 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
ax = me.linechart(sim*0.5, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  1.400438
# 1  sim mean  3.475929
# 2         R  0.712003
# 3        MB  2.075492
# 4      RMSE  2.370523
# 5       IOA  0.372549

# %%
me.evaluation_frame(obs, sim*0.5, df)
# Out:
#       param     value
# 0  obs mean  1.400438
# 1  sim mean  1.737965
# 2         R  0.712003
# 3        MB  0.337527
# 4      RMSE  0.617602
# 5       IOA  0.769212

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(mcipfile,var,shpurban,obsurban,varch)
# Out:
# Get the WSPD10 in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 风速 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
ax = me.linechart(sim*0.5, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  1.757923
# 1  sim mean  3.682824
# 2         R  0.620896
# 3        MB  1.924901
# 4      RMSE  2.433682
# 5       IOA  0.456243

# %%
me.evaluation_frame(obs, sim*0.5, df)
# Out:
#       param     value
# 0  obs mean  1.757923
# 1  sim mean  1.841412
# 2         R  0.620896
# 3        MB  0.083489
# 4      RMSE  0.763539
# 5       IOA  0.784031

# %% [markdown]
# ## 安庆市郊区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
#       2 xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'
# ----> 4 df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
#
# NameError: name 'ncfile' is not defined

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  1.420326
# 1  sim mean  3.321293
# 2         R  0.819258
# 3        MB  1.900967
# 4      RMSE  2.150619
# 5       IOA  0.484681
