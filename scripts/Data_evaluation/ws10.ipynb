# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-07-07*

# %%
import sys
sys.path.append('../../src/')
from namelist import *
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'WSPD10'
varch = '风速'

title = 'WS10'
units = 'm/s'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(mcipfile,var,shpall,obsall,varch)
# Out:
# Get the WSPD10 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 风速 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
ax = me.linechart(sim*0.5, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  1.243123
# 1  sim mean  2.991378
# 2         R  0.711244
# 3        MB  1.748255
# 4      RMSE  1.973520
# 5       IOA  0.387449

# %%
me.evaluation_frame(obs, sim*0.5, df)
# Out:
#       param     value
# 0  obs mean  1.243123
# 1  sim mean  1.495689
# 2         R  0.711244
# 3        MB  0.252566
# 4      RMSE  0.494799
# 5       IOA  0.790894

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(mcipfile,var,shpurban,obsurban,varch)
# Out:
# Get the WSPD10 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 风速 in shape of (720,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
ax = me.linechart(sim*0.5, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  1.521995
# 1  sim mean  3.136412
# 2         R  0.662074
# 3        MB  1.614417
# 4      RMSE  2.026022
# 5       IOA  0.503630

# %%
me.evaluation_frame(obs, sim*0.5, df)
# Out:
#       param     value
# 0  obs mean  1.521995
# 1  sim mean  1.568206
# 2         R  0.662074
# 3        MB  0.046211
# 4      RMSE  0.638818
# 5       IOA  0.813348

# %% [markdown]
# ## 安庆市郊区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the WSPD10 in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 风速 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  1.420326
# 1  sim mean  3.321293
# 2         R  0.819258
# 3        MB  1.900967
# 4      RMSE  2.150619
# 5       IOA  0.484681
