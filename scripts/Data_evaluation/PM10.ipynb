# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-08-09*

# %%
import sys
sys.path.append('../../src/')
import ModelEvaLib as me
from namelist import *

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
var = 'PM10'
varch = 'PM10'

title = '$PM_{10}$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpall,obsall,varch)
# Out:
# Get the PM10 in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the PM10 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  24.944608
# 1  sim mean  20.454517
# 2         R   0.598703
# 3        MB  -4.490090
# 4      RMSE  10.323321
# 5       IOA   0.734807

# %% [markdown]
# ## 安庆市城区

# %%
df, sim, obs = me.get_var(cmaqfile,var,shpurban,obsurban,varch)
# Out:
# Get the PM10 in shape of (744, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the PM10 in shape of (744,)
# data is ready

# %%
ax = me.linechart(sim, obs, timestart, timeend)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  21.804010
# 1  sim mean  24.020855
# 2         R   0.375856
# 3        MB   2.216845
# 4      RMSE  14.409137
# 5       IOA   0.614655
